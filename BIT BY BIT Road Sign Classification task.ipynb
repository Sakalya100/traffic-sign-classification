# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from PIL import Image
import warnings

warnings.filterwarnings('ignore')
np.random.seed(0)
tf.random.set_seed(0)

# %%
cwd = 'D:/My Learning/ML Projects/BitbyBit ML Task/'
os.listdir(cwd)
# Out:
# ['.ipynb_checkpoints',
#  'Meta',
#  'Meta.csv',
#  'Test',
#  'Test.csv',
#  'Train',
#  'Train.csv',
#  'Untitled.ipynb']

# %%
meta = os.listdir(cwd+'/Meta')

meta
# Out:
# ['0.png',
#  '1.png',
#  '10.png',
#  '11.png',
#  '12.png',
#  '13.png',
#  '14.png',
#  '15.png',
#  '16.png',
#  '17.png',
#  '18.png',
#  '19.png',
#  '2.png',
#  '20.png',
#  '21.png',
#  '22.png',
#  '23.png',
#  '24.png',
#  '25.png',
#  '26.png',
#  '27.png',
#  '28.png',
#  '29.png',
#  '3.png',
#  '30.png',
#  '31.png',
#  '32.png',
#  '33.png',
#  '34.png',
#  '35.png',
#  '36.png',
#  '37.png',
#  '38.png',
#  '39.png',
#  '4.png',
#  '40.png',
#  '41.png',
#  '42.png',
#  '5.png',
#  '6.png',
#  '7.png',
#  '8.png',
#  '9.png']

# %%
## Viewing images belonging to each class

plt.figure(figsize=(30,30))
for i, file in enumerate(meta):
    img = Image.open(cwd+"Meta/"+file)
    ax = plt.subplot(9,5,i+1)  #Creating a 9 row 5 column subplot to plot all the images
    ax.imshow(img)
    ax.set_title(file, size=20) #title of each image is set same as file name such as 0.png and so on
    plt.axis('off')
plt.tight_layout()

# %%
# Setting the classes as per symbols as it is not already supplied in the dataset
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles',  
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %% [markdown]
# Data Preprocessing and Data preparation

# %%
train_df = pd.read_csv(cwd+'Train.csv')
train_df.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId  \
# 0     27      26       5       5      22      20       20
# 1     28      27       5       6      23      22       20
# 2     29      26       6       5      24      21       20
# 3     28      27       5       6      23      22       20
# 4     28      26       5       5      23      21       20
#
#                              Path
# 0  Train/20/00020_00000_00000.png
# 1  Train/20/00020_00000_00001.png
# 2  Train/20/00020_00000_00002.png
# 3  Train/20/00020_00000_00003.png
# 4  Train/20/00020_00000_00004.png

# %%
train_df.describe()
# Out:
#               Width        Height        Roi.X1        Roi.Y1        Roi.X2  \
# count  39209.000000  39209.000000  39209.000000  39209.000000  39209.000000
# mean      50.835880     50.328930      5.999515      5.962381     45.197302
# std       24.306933     23.115423      1.475493      1.385440     23.060157
# min       25.000000     25.000000      0.000000      5.000000     20.000000
# 25%       35.000000     35.000000      5.000000      5.000000     29.000000
# 50%       43.000000     43.000000      6.000000      6.000000     38.000000
# 75%       58.000000     58.000000      6.000000      6.000000     53.000000
# max      243.000000    225.000000     20.000000     20.000000    223.000000
#
#              Roi.Y2       ClassId
# count  39209.000000  39209.000000
# mean      44.728379     15.788390
# std       21.971145     12.013238
# min       20.000000      0.000000
# 25%       30.000000      5.000000
# 50%       38.000000     12.000000
# 75%       52.000000     25.000000
# max      205.000000     42.000000

# %%
print(f'minimum width: {train_df.Width.min()}')
print(f'minimum height: {train_df.Height.min()}')
print(f'average width: {train_df.Width.mean()}')
print(f'average height: {train_df.Height.mean()}')
# Out:
# minimum width: 25
# minimum height: 25
# average width: 50.83587951745773
# average height: 50.328929582493814

# %%
train_x =[]
for i in train_df.Path:
    img = Image.open(cwd+i)       # reading image
    img = img.resize((50,50))     # reasizing image
    train_x.append(np.array(img)) # saving image as array to train

train_y = np.array(train_df.ClassId)
train_x = np.array(train_x)
print(train_x.shape)
print(train_y.shape)
# Out:
# (39209, 50, 50, 3)
# (39209,)

# %%
test_df = pd.read_csv(cwd+'Test.csv')
test_df.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId            Path
# 0     53      54       6       5      48      49       16  Test/00000.png
# 1     42      45       5       5      36      40        1  Test/00001.png
# 2     48      52       6       6      43      47       38  Test/00002.png
# 3     27      29       5       5      22      24       33  Test/00003.png
# 4     60      57       5       5      55      52       11  Test/00004.png

# %%
test_x =[]
for i in test_df.Path:
    img = Image.open(cwd+i)
    img = img.resize((50,50))
    test_x.append(np.array(img))

test_y = np.array(test_df.ClassId)
test_x = np.array(test_x)
print(test_x.shape)
print(test_y.shape)
# Out:
# (12630, 50, 50, 3)
# (12630,)

# %%
print(classes[train_y[2]])
plt.imshow(train_x[2])
plt.axis('off')
plt.show()
# Out:
# Dangerous curve right

# %%
## Normalization

xtrain = train_x/255
xtest = test_x/255


# One Hot encoding

ytrain = keras.utils.to_categorical(train_y)
ytest = keras.utils.to_categorical(test_y)

# %% [markdown]
# ## Model Training and Hyperparameter Tuning

# %%
from sklearn.model_selection import train_test_split
xtrain, xvalid, ytrain, yvalid = train_test_split(xtrain, ytrain, test_size=0.2, random_state=0)
print(xtrain.shape)
print(xvalid.shape)
print(ytrain.shape)
print(yvalid.shape)
# Out:
# (31367, 50, 50, 3)
# (7842, 50, 50, 3)
# (31367, 43)
# (7842, 43)

# %%
from keras.layers import Conv2D, MaxPool2D, Dense, Dropout, Flatten

model = keras.models.Sequential()
model.add(Conv2D(filters=32, kernel_size= (5,5), strides=2, activation='relu', padding='same', input_shape=(50,50,3)))
model.add(Conv2D(filters=32, kernel_size=(5,5), strides=2, activation='relu', padding='same'))
model.add(MaxPool2D((2,2), padding='valid'))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=(5,5), strides=2, activation='relu', padding='same'))
model.add(Conv2D(filters=64, kernel_size=(5,5), strides=2, activation='relu', padding='same'))
model.add(MaxPool2D((2,2), padding='valid'))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(300, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(43, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 25, 25, 32)        2432
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 32)        25632
#
#  max_pooling2d (MaxPooling2D  (None, 6, 6, 32)         0
#  )
#
#  dropout (Dropout)           (None, 6, 6, 32)          0
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          51264
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 64)          102464
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 1, 1, 64)          0
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 300)               19500
#
#  dense_1 (Dense)             (None, 200)               60200
#
#  dense_2 (Dense)             (None, 43)                8643
#
# =================================================================
# Total params: 270,135
# Trainable params: 270,135
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
# Compiling the CNN model
model.compile(optimizer='sgd',
             loss='categorical_crossentropy',
             metrics = ['accuracy'])

# %%
earlystop_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights =True)

model_history = model.fit(xtrain,ytrain, epochs=200,
                         validation_data=(xvalid,yvalid),
                         callbacks=[earlystop_cb])
# Out:
# Epoch 1/200
# 981/981 [==============================] - 29s 26ms/step - loss: 3.5652 - accuracy: 0.0631 - val_loss: 3.4716 - val_accuracy: 0.0784
# Epoch 2/200
# 981/981 [==============================] - 25s 26ms/step - loss: 3.3758 - accuracy: 0.1128 - val_loss: 3.0715 - val_accuracy: 0.2142
# Epoch 3/200
# 981/981 [==============================] - 27s 28ms/step - loss: 2.4453 - accuracy: 0.3169 - val_loss: 1.8944 - val_accuracy: 0.4082
# Epoch 4/200
# 981/981 [==============================] - 30s 31ms/step - loss: 1.4457 - accuracy: 0.5530 - val_loss: 1.0650 - val_accuracy: 0.6827
# Epoch 5/200
# 981/981 [==============================] - 29s 29ms/step - loss: 1.0030 - accuracy: 0.6819 - val_loss: 0.8381 - val_accuracy: 0.7344
# Epoch 6/200
# 981/981 [==============================] - 28s 29ms/step - loss: 0.7832 - accuracy: 0.7494 - val_loss: 0.4218 - val_accuracy: 0.8722
# Epoch 7/200
# 981/981 [==============================] - 30s 30ms/step - loss: 0.6216 - accuracy: 0.7982 - val_loss: 0.3777 - val_accuracy: 0.8767
# Epoch 8/200
# 981/981 [==============================] - 29s 29ms/step - loss: 0.5308 - accuracy: 0.8296 - val_loss: 0.3890 - val_accuracy: 0.8716
# Epoch 9/200
# 981/981 [==============================] - 27s 28ms/step - loss: 0.4460 - accuracy: 0.8573 - val_loss: 0.2772 - val_accuracy: 0.9126
# Epoch 10/200
# 981/981 [==============================] - 30s 30ms/step - loss: 0.3888 - accuracy: 0.8763 - val_loss: 0.2900 - val_accuracy: 0.9082
# Epoch 11/200
# 981/981 [==============================] - 28s 29ms/step - loss: 0.3503 - accuracy: 0.8887 - val_loss: 0.2056 - val_accuracy: 0.9464
# Epoch 12/200
# 981/981 [==============================] - 27s 28ms/step - loss: 0.3086 - accuracy: 0.9008 - val_loss: 0.1727 - val_accuracy: 0.9556
# Epoch 13/200
# 981/981 [==============================] - 28s 28ms/step - loss: 0.2816 - accuracy: 0.9112 - val_loss: 0.1545 - val_accuracy: 0.9522
# Epoch 14/200
# 981/981 [==============================] - 33s 34ms/step - loss: 0.2557 - accuracy: 0.9178 - val_loss: 0.1013 - val_accuracy: 0.9717
# Epoch 15/200
# 981/981 [==============================] - 25s 25ms/step - loss: 0.2433 - accuracy: 0.9228 - val_loss: 0.1182 - val_accuracy: 0.9680
# Epoch 16/200
# 981/981 [==============================] - 24s 25ms/step - loss: 0.2282 - accuracy: 0.9277 - val_loss: 0.1015 - val_accuracy: 0.9688
# Epoch 17/200
# 981/981 [==============================] - 24s 24ms/step - loss: 0.1997 - accuracy: 0.9366 - val_loss: 0.1225 - val_accuracy: 0.9643
# Epoch 18/200
# 981/981 [==============================] - 24s 25ms/step - loss: 0.1942 - accuracy: 0.9384 - val_loss: 0.2358 - val_accuracy: 0.9374
# Epoch 19/200
# 981/981 [==============================] - 29s 30ms/step - loss: 0.1825 - accuracy: 0.9411 - val_loss: 0.0783 - val_accuracy: 0.9782
# Epoch 20/200
# 981/981 [==============================] - 27s 27ms/step - loss: 0.1664 - accuracy: 0.9479 - val_loss: 0.0649 - val_accuracy: 0.9836
# Epoch 21/200
# 981/981 [==============================] - 25s 25ms/step - loss: 0.1631 - accuracy: 0.9467 - val_loss: 0.0726 - val_accuracy: 0.9811
# Epoch 22/200
# 981/981 [==============================] - 25s 26ms/step - loss: 0.1453 - accuracy: 0.9543 - val_loss: 0.1111 - val_accuracy: 0.9676
# Epoch 23/200
# 981/981 [==============================] - 26s 26ms/step - loss: 0.1428 - accuracy: 0.9552 - val_loss: 0.0624 - val_accuracy: 0.9833
# Epoch 24/200
# 981/981 [==============================] - 25s 25ms/step - loss: 0.1314 - accuracy: 0.9574 - val_loss: 0.0541 - val_accuracy: 0.9855
# Epoch 25/200
# 981/981 [==============================] - 26s 26ms/step - loss: 0.1250 - accuracy: 0.9601 - val_loss: 0.0530 - val_accuracy: 0.9866
# Epoch 26/200
# 981/981 [==============================] - 25s 25ms/step - loss: 0.1197 - accuracy: 0.9626 - val_loss: 0.0507 - val_accuracy: 0.9864
# Epoch 27/200
# 981/981 [==============================] - 25s 26ms/step - loss: 0.1151 - accuracy: 0.9636 - val_loss: 0.0544 - val_accuracy: 0.9874
# Epoch 28/200
# 981/981 [==============================] - 25s 26ms/step - loss: 0.1115 - accuracy: 0.9647 - val_loss: 0.0508 - val_accuracy: 0.9864
# Epoch 29/200
# 981/981 [==============================] - 27s 27ms/step - loss: 0.0988 - accuracy: 0.9696 - val_loss: 0.0578 - val_accuracy: 0.9838
# Epoch 30/200
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0954 - accuracy: 0.9689 - val_loss: 0.0521 - val_accuracy: 0.9866
# Epoch 31/200
# 981/981 [==============================] - 25s 25ms/step - loss: 0.0906 - accuracy: 0.9711 - val_loss: 0.0527 - val_accuracy: 0.9856

# %%
pd.DataFrame(model_history.history).plot()
# Out:
# <AxesSubplot:>

# %%
## Evaluating the model

loss, accuracy = model.evaluate(xtest,ytest)
print(f'Loss = {loss:.2f}\naccuracy = {accuracy*100:.2f}%')
# Out:
# 395/395 [==============================] - 2s 4ms/step - loss: 0.4117 - accuracy: 0.9093
# Loss = 0.41
# accuracy = 90.93%

# %%
## Making predictions

prob = model.predict(xtest)
pred = np.argmax(prob, axis=-1)

# %%
# print(prob[1])
plt.figure(figsize=(30,30))
for i in range(50):
    ax = plt.subplot(5,10,i+1)
    ax.imshow(xtest[i])
    ax.set_title(f'predicted: {classes[pred[i]]}\nactual:{classes[test_y[i]]}')
    plt.axis('off')
plt.tight_layout()
plt.show()
